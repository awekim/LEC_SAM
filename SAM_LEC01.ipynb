# %% [markdown]
# # Statistical Analytic Methods
# #### Prof. KKIM, Yonsei University
# ### LEC01. Intorudction

# %%
print("hello")
# Out:
# hello

# %%
1+1
# Out:
# 2

# %%
import pandas as pd

# %% [markdown]
# Hi
# # Hi
# ## Hi
# ### Hi
#
# Hi my name is **Yonsei**.

# %% [markdown]
# # Welcome to Statistical Analytic Methods
#
# Lecture01's **exercise**.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Define the path to the image file
image_file_path = '/content/drive/MyDrive/yu.jpg'

try:
    # Open the image file
    img = Image.open(image_file_path)

    # Display the image
    plt.imshow(img)
    plt.axis('off') # Hide axes
    plt.title('Loaded Image: Yonsei')
    plt.show()

    print(f"Successfully loaded and displayed image from {image_file_path}")
except FileNotFoundError:
    print(f"Error: The file '{image_file_path}' was not found. Please check the path and filename.")
except Exception as e:
    print(f"An error occurred while loading or displaying the image: {e}")
# Out:
# Error: The file '/content/drive/MyDrive/yu.png' was not found. Please check the path and filename.

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Define the path to the image file
image_file_path = '/content/drive/MyDrive/[YU]/[Lecture]/[SAM]/01_SAM_Practice/SAM_LEC01/yu.jpg'

try:
    # Open the image file
    img = Image.open(image_file_path)

    # Display the image
    plt.imshow(img)
    plt.axis('off') # Hide axes
    plt.title('Loaded Image: Yonsei')
    plt.show()

    print(f"Successfully loaded and displayed image from {image_file_path}")
except FileNotFoundError:
    print(f"Error: The file '{image_file_path}' was not found. Please check the path and filename.")
except Exception as e:
    print(f"An error occurred while loading or displaying the image: {e}")
# Out:
# Successfully loaded and displayed image from /content/drive/MyDrive/[YU]/[Lecture]/[SAM]/01_SAM_Practice/SAM_LEC01/yu.jpg

# %% [markdown]
# #Heading 1
# ##Heading 2
# ###Heading 3
# ####Heading 4
# #####Heeading 5
# ######Heading 6

# %% [markdown]
# **bold** <br>
# __bold__ <br>
# ___bold & italic___ <br>
# *italic* <br>
# _italic_ <br>
# ~~strike~~ <br>
# <u>underbar</u><br>

# %% [markdown]
# # Welcome to [Yonsei University](https://www.yonsei.ac.kr/sc/index.do).
#
# > Introduction
# > * Name: Keungoui KIM
# > * Age: 21
# > * MBTI: CUTE
# > * Major: STP
# > * Tier: Platinum
